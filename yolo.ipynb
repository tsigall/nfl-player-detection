# %%
import torch
from IPython.display import Image
import matplotlib.pyplot as plt
import shutil
import os
import cv2

print(torch.__version__)
# Out:
# 2.2.1+cu121

# %%
# %cd drive/Othercomputers/Mac/dsan6600
# Out:
# /content/drive/Othercomputers/Mac/dsan6600

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="zEq7bZFwr1BHWEiJ2192")
project = rf.workspace("project-1tb2x").project("project-u8hk9")
version = project.version(1)
dataset = version.download("yolov5")

# %%
# %cd /content/drive/Othercomputers/Mac/dsan6600/yolov5
# Out:
# /content/drive/Othercomputers/Mac/dsan6600/yolov5

# %%
# !python train.py --img 640 --epochs 3 --data Project-1/data.yaml --weights yolov5s.pt

# %%
# %pip install comet_ml --quiet

# %%
import comet_ml
comet_ml.init(project_name='comet-example-yolov5')
# Out:
# Please paste your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)
# Comet API key: ··········
# COMET INFO: Valid Comet API Key saved in /content/drive/MyDrive/.comet.config (set COMET_CONFIG to change where it is saved).

# %%
# %cd /content/drive/Othercomputers/Mac/dsan6600/yolov5
# Out:
# /content/drive/Othercomputers/Mac/dsan6600/yolov5

# %%
# !python train.py \
--img 640 \
--batch 16 \
--epochs 5 \
--data Project-1/data.yaml \
--weights yolov5s.pt \
--bbox_interval 1 \
--save-period 1
# Out:
# 2024-03-19 17:09:53.280194: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-19 17:09:53.280301: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-19 17:09:53.283364: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
